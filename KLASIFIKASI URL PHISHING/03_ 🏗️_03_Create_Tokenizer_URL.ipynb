# %% [markdown]
# # 📢 File explanation!!

# %% [markdown]
# Pada file ini bertujuan untuk membuat corpus dari dataset df_url_random_preprocess.csv yang telah dipreprocessing

# %% [markdown]
# # 🎯 **Step 0: Import library**
# ---

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import json

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
plt.style.use('seaborn')
# Out:
# <ipython-input-2-4a43041a1d49>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🎯 **Step 1: Load Dataset**
# ---

# %%
# path = '/content/drive/MyDrive/TUGAS AKHIR/Dataset/URL/df_url_random_preprocess.csv'

df_url = pd.read_csv('/content/drive/MyDrive/TUGAS AKHIR/Notebook/Dataset/URL/new_url.csv')

df_url.head()
# Out:
#                                                  URL  Category
# 0                  https://ats-cool-site.webflow.io/  phishing
# 1  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 2  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 3                      https://m8vqz27f.square.site/  phishing
# 4  https://docs.google.com/presentation/d/e/2PACX...  phishing

# %% [markdown]
# # 🎯 **Step 2: Split data into feature and label**
# ---

# %%
X = df_url['URL']

y = df_url['Category']

# %% [markdown]
# # 🎯 **Step 3: Processing X**
# ---

# %% [markdown]
# ## ✨ 3.1 - Create Char Level Corpus for Tokenizing and Padding

# %%
X = [str(url) for url in X]

tokenizer_char_level = Tokenizer(num_words=None, oov_token='<OOV>', char_level=True)
tokenizer_char_level.fit_on_texts(X)
# X_sequences_char_level = tokenizer_char_level.texts_to_sequences(X)
# X_padded_char_level = pad_sequences(X_sequences_char_level, padding='post', truncating='post', maxlen=2000)

# # Build vocabulary
# vocab_size_char_level = len(tokenizer_char_level.word_index) + 1

# X_padded_char_level

# %%
len(tokenizer_char_level.word_index)
# Out:
# 937

# %%
tokenizer_char_level.word_index
# Out:
# {'<OOV>': 1,
#  't': 2,
#  '/': 3,
#  'e': 4,
#  's': 5,
#  'a': 6,
#  'o': 7,
#  'p': 8,
#  'i': 9,
#  'c': 10,
#  'r': 11,
#  '.': 12,
#  'h': 13,
#  'n': 14,
#  'm': 15,
#  'l': 16,
#  'w': 17,
#  'd': 18,
#  '-': 19,
#  'f': 20,
#  'b': 21,
#  'u': 22,
#  'g': 23,
#  ':': 24,
#  'y': 25,
#  'v': 26,
#  'k': 27,
#  '2': 28,
#  '0': 29,
#  '3': 30,
#  '1': 31,
#  'x': 32,
#  '4': 33,
#  '5': 34,
#  'z': 35,
#  '7': 36,
#  'j': 37,
#  '6': 38,
#  '8': 39,
#  'q': 40,
#  '9': 41,
#  '%': 42,
#  '=': 43,
#  '_': 44,
#  '&': 45,
#  '?': 46,
#  ';': 47,
#  '#': 48,
#  '+': 49,
#  ' ': 50,
#  ',': 51,
#  '@': 52,
#  'ا': 53,
#  '|': 54,
#  'ر': 55,
#  'ن': 56,
#  'م': 57,
#  'ل': 58,
#  'ی': 59,
#  'و': 60,
#  ')': 61,
#  '(': 62,
#  'ت': 63,
#  'د': 64,
#  'ب': 65,
#  '!': 66,
#  'س': 67,
#  'ه': 68,
#  'ي': 69,
#  '*': 70,
#  '~': 71,
#  'ش': 72,
#  ']': 73,
#  '[': 74,
#  'и': 75,
#  'а': 76,
#  'р': 77,
#  'е': 78,
#  'ع': 79,
#  'о': 80,
#  'خ': 81,
#  'ک': 82,
#  'ف': 83,
#  'ز': 84,
#  'н': 85,
#  'т': 86,
#  '$': 87,
#  'ح': 88,
#  'ق': 89,
#  'ج': 90,
#  'с': 91,
#  'л': 92,
#  'в': 93,
#  'ة': 94,
#  'گ': 95,
#  'آ': 96,
#  'к': 97,
#  'া': 98,
#  'ك': 99,
#  'à': 100,
#  'پ': 101,
#  'д': 102,
#  'أ': 103,
#  '\t': 104,
#  'ص': 105,
#  'п': 106,
#  'ে': 107,
#  '¸': 108,
#  'ร': 109,
#  'ว': 110,
#  'ط': 111,
#  "'": 112,
#  '注': 113,
#  '册': 114,
#  'น': 115,
#  'า': 116,
#  '’': 117,
#  'г': 118,
#  'ั': 119,
#  'у': 120,
#  'æ': 121,
#  'ি': 122,
#  'র': 123,
#  'ï': 124,
#  'ท': 125,
#  'ф': 126,
#  'з': 127,
#  'б': 128,
#  'é': 129,
#  'ى': 130,
#  'ы': 131,
#  'غ': 132,
#  'ض': 133,
#  '\u200c': 134,
#  'ш': 135,
#  'å': 136,
#  'ค': 137,
#  'บ': 138,
#  'ذ': 139,
#  'ó': 140,
#  'ã': 141,
#  'ä': 142,
#  'ক': 143,
#  'چ': 144,
#  'ü': 145,
#  'м': 146,
#  'อ': 147,
#  'ย': 148,
#  'ظ': 149,
#  'ç': 150,
#  'ন': 151,
#  '্': 152,
#  'ব': 153,
#  'ল': 154,
#  '\xa0': 155,
#  'เ': 156,
#  'ี': 157,
#  'إ': 158,
#  '\x80': 159,
#  'ء': 160,
#  'ট': 161,
#  'ئ': 162,
#  'ン': 163,
#  '¾': 164,
#  '½': 165,
#  '§': 166,
#  'ม': 167,
#  '่': 168,
#  'โ': 169,
#  'ง': 170,
#  'ล': 171,
#  'ц': 172,
#  'х': 173,
#  'ก': 174,
#  'ত': 175,
#  'য়': 176,
#  'す': 177,
#  'の': 178,
#  'ด': 179,
#  'ต': 180,
#  'ไ': 181,
#  'ч': 182,
#  'í': 183,
#  '기': 184,
#  'è': 185,
#  '\x8a': 186,
#  '¼': 187,
#  '\x9f': 188,
#  '\x84': 189,
#  '®': 190,
#  'й': 191,
#  'য': 192,
#  '의': 193,
#  'ø': 194,
#  '°': 195,
#  'ð': 196,
#  '이': 197,
#  'ו': 198,
#  '¹': 199,
#  'ิ': 200,
#  '\x82': 201,
#  '\x9c': 202,
#  'ছ': 203,
#  'প': 204,
#  'ि': 205,
#  '에': 206,
#  '리': 207,
#  '人': 208,
#  'ซ': 209,
#  '้': 210,
#  'জ': 211,
#  'я': 212,
#  '>': 213,
#  '女': 214,
#  'ث': 215,
#  'ー': 216,
#  'י': 217,
#  'ת': 218,
#  'ù': 219,
#  '}': 220,
#  'ь': 221,
#  'ป': 222,
#  'ј': 223,
#  '์': 224,
#  'ุ': 225,
#  'お': 226,
#  'ạ': 227,
#  '스': 228,
#  '\x96': 229,
#  '´': 230,
#  '¤': 231,
#  '\x95': 232,
#  'ա': 233,
#  'দ': 234,
#  'ু': 235,
#  '・': 236,
#  'र': 237,
#  '는': 238,
#  'ห': 239,
#  'ู': 240,
#  'ń': 241,
#  '지': 242,
#  'ö': 243,
#  'স': 244,
#  '—': 245,
#  '라': 246,
#  '中': 247,
#  '…': 248,
#  'ル': 249,
#  '상': 250,
#  'σ': 251,
#  'ο': 252,
#  '事': 253,
#  '©': 254,
#  '新': 255,
#  'š': 256,
#  '²': 257,
#  '{': 258,
#  'ส': 259,
#  'ช': 260,
#  'ژ': 261,
#  'り': 262,
#  'đ': 263,
#  'â': 264,
#  '"': 265,
#  '서': 266,
#  '버': 267,
#  '品': 268,
#  '作': 269,
#  '¯': 270,
#  '»': 271,
#  '\x98': 272,
#  '\x85': 273,
#  '³': 274,
#  '\xad': 275,
#  '可': 276,
#  'հ': 277,
#  'ড়': 278,
#  'み': 279,
#  'ा': 280,
#  'ड': 281,
#  'क': 282,
#  'स': 283,
#  '트': 284,
#  '만': 285,
#  'э': 286,
#  'ื': 287,
#  'ะ': 288,
#  'ク': 289,
#  'ž': 290,
#  '±': 291,
#  '大': 292,
#  '최': 293,
#  '고': 294,
#  '다': 295,
#  'á': 296,
#  'μ': 297,
#  'ও': 298,
#  '‘': 299,
#  'イ': 300,
#  'ম': 301,
#  'হ': 302,
#  '–': 303,
#  'ই': 304,
#  'フ': 305,
#  'ァ': 306,
#  '家': 307,
#  '北': 308,
#  '게': 309,
#  'ή': 310,
#  'λ': 311,
#  '工': 312,
#  'ж': 313,
#  'η': 314,
#  'τ': 315,
#  'δ': 316,
#  '魔': 317,
#  '的': 318,
#  'っ': 319,
#  'ち': 320,
#  '하': 321,
#  '은': 322,
#  '২': 323,
#  'る': 324,
#  '¥': 325,
#  'ה': 326,
#  'כ': 327,
#  '\x94': 328,
#  'ב': 329,
#  '\n': 330,
#  '¿': 331,
#  'し': 332,
#  'ろ': 333,
#  'ข': 334,
#  'แ': 335,
#  '็': 336,
#  'ถ': 337,
#  'な': 338,
#  'ư': 339,
#  '큐': 340,
#  '가': 341,
#  '되': 342,
#  '어': 343,
#  '사': 344,
#  '«': 345,
#  '物': 346,
#  '<': 347,
#  '\x87': 348,
#  '\x83': 349,
#  '¶': 350,
#  '\x81': 351,
#  '\x89': 352,
#  'ভ': 353,
#  'ग': 354,
#  'ल': 355,
#  '인': 356,
#  '무': 357,
#  '귀': 358,
#  '쓰': 359,
#  '레': 360,
#  '들': 361,
#  '중': 362,
#  'ց': 363,
#  'ր': 364,
#  '피': 365,
#  '자': 366,
#  '달': 367,
#  '와': 368,
#  'ษ': 369,
#  'พ': 370,
#  'º': 371,
#  '“': 372,
#  '”': 373,
#  'ю': 374,
#  'щ': 375,
#  'ピ': 376,
#  'ッ': 377,
#  '\x8c': 378,
#  '\x9b': 379,
#  'ภ': 380,
#  'マ': 381,
#  'ガ': 382,
#  '한': 383,
#  '۹': 384,
#  'ী': 385,
#  'ৃ': 386,
#  'ñ': 387,
#  '男': 388,
#  'न': 389,
#  'ी': 390,
#  '메': 391,
#  '전': 392,
#  'і': 393,
#  'ジ': 394,
#  'め': 395,
#  'қ': 396,
#  '슈': 397,
#  '회': 398,
#  '小': 399,
#  '程': 400,
#  '연': 401,
#  '애': 402,
#  'ナ': 403,
#  '강': 404,
#  '법': 405,
#  '無': 406,
#  '出': 407,
#  'ং': 408,
#  '০': 409,
#  'ো': 410,
#  'ć': 411,
#  '\x91': 412,
#  'ワ': 413,
#  'キ': 414,
#  '社': 415,
#  'タ': 416,
#  'リ': 417,
#  '原': 418,
#  '爱': 419,
#  '화': 420,
#  'ス': 421,
#  '左': 422,
#  '里': 423,
#  '세': 424,
#  '내': 425,
#  '上': 426,
#  '衣': 427,
#  '크': 428,
#  '오': 429,
#  '시': 430,
#  'ρ': 431,
#  'α': 432,
#  'ム': 433,
#  'ド': 434,
#  '学': 435,
#  'π': 436,
#  'θ': 437,
#  '을': 438,
#  '거': 439,
#  '致': 440,
#  '功': 441,
#  '悪': 442,
#  'だ': 443,
#  'た': 444,
#  '任': 445,
#  'ㅋ': 446,
#  'ㄷ': 447,
#  '루': 448,
#  '목': 449,
#  '默': 450,
#  '了': 451,
#  '片': 452,
#  'を': 453,
#  'আ': 454,
#  'গ': 455,
#  'か': 456,
#  'ト': 457,
#  '\x97': 458,
#  '第': 459,
#  'ם': 460,
#  '良': 461,
#  '姐': 462,
#  '后': 463,
#  '翘': 464,
#  '本': 465,
#  'ī': 466,
#  'せ': 467,
#  '¡': 468,
#  '最': 469,
#  '气': 470,
#  '嫩': 471,
#  '神': 472,
#  '比': 473,
#  '\x9d': 474,
#  '¢': 475,
#  'ঁ': 476,
#  '\x99': 477,
#  'ש': 478,
#  'ר': 479,
#  'מ': 480,
#  'נ': 481,
#  'ק': 482,
#  '角': 483,
#  '\\': 484,
#  '�': 485,
#  '๊': 486,
#  'ฟ': 487,
#  'ผ': 488,
#  '広': 489,
#  '瀬': 490,
#  'ờ': 491,
#  'ọ': 492,
#  '린': 493,
#  '님': 494,
#  '农': 495,
#  '产': 496,
#  '粮': 497,
#  '油': 498,
#  '谷': 499,
#  '类': 500,
#  '\x8e': 501,
#  '¨': 502,
#  '\x90': 503,
#  '\x9a': 504,
#  '\x8b': 505,
#  'ê': 506,
#  '麥': 507,
#  '．': 508,
#  '史': 509,
#  '萊': 510,
#  '平': 511,
#  '恩': 512,
#  '（': 513,
#  '）': 514,
#  'պ': 515,
#  'կ': 516,
#  '৫': 517,
#  'উ': 518,
#  'চ': 519,
#  '胸': 520,
#  '揉': 521,
#  '触': 522,
#  '潤': 523,
#  '波': 524,
#  'ध': 525,
#  'औ': 526,
#  'े': 527,
#  '폐': 528,
#  '쌍': 529,
#  '용': 530,
#  '병': 531,
#  '왕': 532,
#  '환': 533,
#  '传': 534,
#  '播': 535,
#  '٣': 536,
#  '١': 537,
#  '٥': 538,
#  '観': 539,
#  '光': 540,
#  '통': 541,
#  '액': 542,
#  '작': 543,
#  '성': 544,
#  'ռ': 545,
#  'ն': 546,
#  'լ': 547,
#  'գ': 548,
#  'ո': 549,
#  'ղ': 550,
#  '배': 551,
#  '부': 552,
#  '골': 553,
#  '드': 554,
#  '팰': 555,
#  '艾': 556,
#  '黛': 557,
#  '兒': 558,
#  '街': 559,
#  '頭': 560,
#  '素': 561,
#  'จ': 562,
#  '⚽': 563,
#  '️': 564,
#  'ポ': 565,
#  'プ': 566,
#  'テ': 567,
#  '喜': 568,
#  '揚': 569,
#  'ª': 570,
#  '力': 571,
#  '金': 572,
#  '刚': 573,
#  '掌': 574,
#  'ď': 575,
#  'ý': 576,
#  '선': 577,
#  '녀': 578,
#  '탕': 579,
#  '도': 580,
#  '난': 581,
#  '건': 582,
#  '생': 583,
#  '충': 584,
#  'ự': 585,
#  '협': 586,
#  '악': 587,
#  '당': 588,
#  '딸': 589,
#  '입': 590,
#  '니': 591,
#  'ষ': 592,
#  '袜': 593,
#  'म': 594,
#  'ु': 595,
#  'ख': 596,
#  'ज': 597,
#  'त': 598,
#  'व': 599,
#  '카': 600,
#  '노': 601,
#  '키': 602,
#  '미': 603,
#  '외': 604,
#  'オ': 605,
#  'ラ': 606,
#  'カ': 607,
#  'ノ': 608,
#  'ә': 609,
#  '룹': 610,
#  '隽': 611,
#  '永': 612,
#  '智': 613,
#  '库': 614,
#  '序': 615,
#  '천': 616,
#  '재': 617,
#  '子': 618,
#  'ア': 619,
#  '퍼': 620,
#  '브': 621,
#  '딩': 622,
#  '彼': 623,
#  '氏': 624,
#  'に': 625,
#  '斷': 626,
#  'で': 627,
#  'ঋ': 628,
#  'ণ': 629,
#  '১': 630,
#  'ধ': 631,
#  'ূ': 632,
#  'ُ': 633,
#  '려': 634,
#  '일': 635,
#  '؟': 636,
#  '水': 637,
#  '晶': 638,
#  '饰': 639,
#  '秘': 640,
#  '書': 641,
#  '辰': 642,
#  '东': 643,
#  'অ': 644,
#  'ফ': 645,
#  'ড': 646,
#  '会': 647,
#  'シ': 648,
#  'ズ': 649,
#  '铃': 650,
#  '蜜': 651,
#  '莉': 652,
#  'ؤ': 653,
#  '새': 654,
#  '벽': 655,
#  'ٓ': 656,
#  'ダ': 657,
#  'ソ': 658,
#  'ウ': 659,
#  'ơ': 660,
#  'ì': 661,
#  '庄': 662,
#  '계': 663,
#  '관': 664,
#  '집': 665,
#  '착': 666,
#  '亚': 667,
#  'ú': 668,
#  '마': 669,
#  '롤': 670,
#  '즌': 671,
#  '테': 672,
#  '원': 673,
#  'घ': 674,
#  'ो': 675,
#  'ं': 676,
#  '變': 677,
#  '態': 678,
#  '另': 679,
#  '類': 680,
#  'ญ': 681,
#  'ธ': 682,
#  'φ': 683,
#  'ヨ': 684,
#  '辽': 685,
#  '宁': 686,
#  '技': 687,
#  '术': 688,
#  '商': 689,
#  '管': 690,
#  '理': 691,
#  '院': 692,
#  '열': 693,
#  'ż': 694,
#  'ζ': 695,
#  'ω': 696,
#  'ύ': 697,
#  'γ': 698,
#  'ι': 699,
#  '쉼': 700,
#  '없': 701,
#  '간': 702,
#  '슬': 703,
#  '러': 704,
#  '너': 705,
#  '恶': 706,
#  '般': 707,
#  '你': 708,
#  '们': 709,
#  '津': 710,
#  '介': 711,
#  '古': 712,
#  '場': 713,
#  '君': 714,
#  'へ': 715,
#  '灰': 716,
#  '羽': 717,
#  '漢': 718,
#  '化': 719,
#  '組': 720,
#  '民': 721,
#  '务': 722,
#  '系': 723,
#  '统': 724,
#  '흑': 725,
#  '막': 726,
#  '줄': 727,
#  '놓': 728,
#  '쳐': 729,
#  '렸': 730,
#  '田': 731,
#  '村': 732,
#  '保': 733,
#  '乃': 734,
#  '能': 735,
#  '線': 736,
#  '有': 737,
#  '更': 738,
#  '多': 739,
#  '以': 740,
#  '看': 741,
#  '石': 742,
#  '岡': 743,
#  '真': 744,
#  'č': 745,
#  '۷': 746,
#  '未': 747,
#  '解': 748,
#  '決': 749,
#  '件': 750,
#  '追': 751,
#  'う': 752,
#  '밤': 753,
#  '양': 754,
#  '함': 755,
#  '께': 756,
#  '৬': 757,
#  '曲': 758,
#  '法': 759,
#  '源': 760,
#  '資': 761,
#  '料': 762,
#  '正': 763,
#  '確': 764,
#  '靠': 765,
#  '彩': 766,
#  '限': 767,
#  '티': 768,
#  '아': 769,
#  'ā': 770,
#  '╎': 771,
#  '密': 772,
#  '室': 773,
#  '逃': 774,
#  '脱': 775,
#  '四': 776,
#  '季': 777,
#  'ד': 778,
#  'ח': 779,
#  'ג': 780,
#  'ס': 781,
#  '主': 782,
#  'ł': 783,
#  '복': 784,
#  '종': 785,
#  '요': 786,
#  '泡': 787,
#  '达': 788,
#  '岁': 789,
#  '前': 790,
#  '凸': 791,
#  '温': 792,
#  '柔': 793,
#  '体': 794,
#  '贴': 795,
#  '缠': 796,
#  '绵': 797,
#  '悱': 798,
#  '恻': 799,
#  '共': 800,
#  '沐': 801,
#  '河': 802,
#  '대': 803,
#  '日': 804,
#  '束': 805,
#  '縛': 806,
#  'セ': 807,
#  'ē': 808,
#  'ū': 809,
#  'ķ': 810,
#  'ņ': 811,
#  '明': 812,
#  'つ': 813,
#  'む': 814,
#  'ぎ': 815,
#  'そ': 816,
#  '着': 817,
#  '替': 818,
#  'え': 819,
#  '形': 820,
#  'は': 821,
#  '恋': 822,
#  '옥': 823,
#  '독': 824,
#  '식': 825,
#  '\x92': 826,
#  '流': 827,
#  '超': 828,
#  '模': 829,
#  '极': 830,
#  '阿': 831,
#  '朱': 832,
#  '私': 833,
#  '拍': 834,
#  '肛': 835,
#  '塞': 836,
#  '猫': 837,
#  '郎': 838,
#  '挺': 839,
#  '乳': 840,
#  '粒': 841,
#  '鲜': 842,
#  '紧': 843,
#  '白': 844,
#  '虎': 845,
#  '无': 846,
#  '与': 847,
#  '伦': 848,
#  '质': 849,
#  '¦': 850,
#  '疯': 851,
#  '狂': 852,
#  '外': 853,
#  '星': 854,
#  '具': 855,
#  '機': 856,
#  '표': 857,
#  '렙': 858,
#  '염': 859,
#  'ศ': 860,
#  'ฏ': 861,
#  'ำ': 862,
#  '盆': 863,
#  '底': 864,
#  '治': 865,
#  '疗': 866,
#  '仪': 867,
#  'থ': 868,
#  '優': 869,
#  'ホ': 870,
#  '見': 871,
#  'て': 872,
#  '下': 873,
#  'さ': 874,
#  'い': 875,
#  '紺': 876,
#  '野': 877,
#  'ひ': 878,
#  '記': 879,
#  '🦡': 880,
#  '\x9e': 881,
#  '戯': 882,
#  'ë': 883,
#  '홈': 884,
#  '늘': 885,
#  '획': 886,
#  '품': 887,
#  'ぼ': 888,
#  'ざ': 889,
#  'く': 890,
#  '！': 891,
#  'ע': 892,
#  'ץ': 893,
#  'א': 894,
#  '包': 895,
#  '臀': 896,
#  '裙': 897,
#  '王': 898,
#  '城': 899,
#  'খ': 900,
#  'শ': 901,
#  '棲': 902,
#  '許': 903,
#  'ہ': 904,
#  'ں': 905,
#  '加': 906,
#  '勒': 907,
#  '執': 908,
#  '愛': 909,
#  '撫': 910,
#  '喫': 911,
#  '茶': 912,
#  '章': 913,
#  '霜': 914,
#  '降': 915,
#  '租': 916,
#  '屋': 917,
#  '香': 918,
#  '港': 919,
#  '島': 920,
#  '半': 921,
#  '山': 922,
#  '天': 923,
#  '\x86': 924,
#  '必': 925,
#  '備': 926,
#  '直': 927,
#  '兵': 928,
#  '哥': 929,
#  '東': 930,
#  '方': 931,
#  '橋': 932,
#  'あ': 933,
#  '타': 934,
#  '프': 935,
#  'ז': 936,
#  'ט': 937}

# %%
tokenizer_char_json = tokenizer_char_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/TUGAS AKHIR/Notebook/URL/Tokenizer/new_tokenizer_char_level.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_char_json))

# %% [markdown]
# ## ✨ 3.1 - Create Word Level Corpus for Tokenizing and Padding

# %%
tokenizer_word_level = Tokenizer(num_words=None, oov_token='<OOV>')
tokenizer_word_level.fit_on_texts(X)
# X_sequences_word_level = tokenizer_word_level.texts_to_sequences(X)
# X_padded_word_level = pad_sequences(X_sequences_word_level, padding='post', truncating='post', maxlen=2000)

# # Build vocabulary
# vocab_size_word_level = len(tokenizer_word_level.word_index) + 1

# X_padded_word_level

# %%
len(tokenizer_word_level.word_index)
# Out:
# 153816

# %%
tokenizer_word_level.word_index
# Out:
# {'<OOV>': 1,
#  'https': 2,
#  'com': 3,
#  'www': 4,
#  'ipfs': 5,
#  'html': 6,
#  'http': 7,
#  'amp': 8,
#  'dev': 9,
#  'false': 10,
#  'pub': 11,
#  'google': 12,
#  'de': 13,
#  'cf': 14,
#  'org': 15,
#  'e': 16,
#  'weeblysite': 17,
#  'd8': 18,
#  'd': 19,
#  'start': 20,
#  'cloudflare': 21,
#  'docs': 22,
#  'php': 23,
#  'ru': 24,
#  'en': 25,
#  'presentation': 26,
#  '2pacx': 27,
#  'loop': 28,
#  'delayms': 29,
#  '3000': 30,
#  'pages': 31,
#  'net': 32,
#  'app': 33,
#  'id': 34,
#  'r2': 35,
#  'network': 36,
#  'co': 37,
#  'd9': 38,
#  'eth': 39,
#  'aragon': 40,
#  'index': 41,
#  '1': 42,
#  'io': 43,
#  'web': 44,
#  'top': 45,
#  'category': 46,
#  'news': 47,
#  'webmail': 48,
#  '2022': 49,
#  'workers': 50,
#  'and': 51,
#  'firebaseapp': 52,
#  'new': 53,
#  'in': 54,
#  'site': 55,
#  '0': 56,
#  'us': 57,
#  'cn': 58,
#  '10': 59,
#  'p': 60,
#  'fr': 61,
#  'my': 62,
#  'home': 63,
#  'the': 64,
#  'to': 65,
#  'uk': 66,
#  'weebly': 67,
#  'page': 68,
#  'a': 69,
#  'e3': 70,
#  'edu': 71,
#  'me': 72,
#  'link': 73,
#  '2f': 74,
#  'a7': 75,
#  'adobe': 76,
#  'express': 77,
#  'd0': 78,
#  'webpage': 79,
#  '2': 80,
#  'utm': 81,
#  'e0': 82,
#  'login': 83,
#  'it': 84,
#  'jp': 85,
#  'of': 86,
#  's': 87,
#  'about': 88,
#  'pl': 89,
#  'i': 90,
#  'att': 91,
#  'view': 92,
#  'c': 93,
#  'slide': 94,
#  'for': 95,
#  'tag': 96,
#  'b8': 97,
#  'htm': 98,
#  'gov': 99,
#  'info': 100,
#  'content': 101,
#  'products': 102,
#  'wixsite': 103,
#  'aspx': 104,
#  'true': 105,
#  't': 106,
#  'sites': 107,
#  'duckdns': 108,
#  'br': 109,
#  '81': 110,
#  'search': 111,
#  '3a': 112,
#  '82': 113,
#  'at': 114,
#  'wp': 115,
#  'online': 116,
#  'accounts': 117,
#  'blog': 118,
#  'tinyurl': 119,
#  'do': 120,
#  'au': 121,
#  '88': 122,
#  'b1': 123,
#  'url': 124,
#  'usps': 125,
#  'nl': 126,
#  'services': 127,
#  '84': 128,
#  'video': 129,
#  '83': 130,
#  'shop': 131,
#  'tv': 132,
#  '8c': 133,
#  'es': 134,
#  'best': 135,
#  'ac': 136,
#  'mail': 137,
#  '85': 138,
#  'se': 139,
#  'xrealip': 140,
#  'ly': 141,
#  '86': 142,
#  'product': 143,
#  'webcindario': 144,
#  'be': 145,
#  'nftstorage': 146,
#  '443': 147,
#  'ca': 148,
#  'facebook': 149,
#  'af': 150,
#  'source': 151,
#  'twitter': 152,
#  '3': 153,
#  'v': 154,
#  'catalog': 155,
#  'ifkv': 156,
#  'db': 157,
#  'collections': 158,
#  'aa': 159,
#  'service': 160,
#  'is': 161,
#  'e5': 162,
#  'business': 163,
#  'ch': 164,
#  'la': 165,
#  'cc': 166,
#  '4': 167,
#  'pdf': 168,
#  'eu': 169,
#  'blogspot': 170,
#  '20': 171,
#  'u': 172,
#  'd1': 173,
#  'x': 174,
#  'on': 175,
#  '1209600': 176,
#  'world': 177,
#  '43': 178,
#  '5c': 179,
#  'continue': 180,
#  '107': 181,
#  'article': 182,
#  'b3': 183,
#  'b9': 184,
#  'list': 185,
#  'm': 186,
#  '87': 187,
#  'telstra': 188,
#  'square': 189,
#  'media': 190,
#  'l': 191,
#  'a8': 192,
#  'support': 193,
#  'usp': 194,
#  'with': 195,
#  'email': 196,
#  'signin': 197,
#  '92': 198,
#  'contact': 199,
#  'ua': 200,
#  'tr': 201,
#  'user': 202,
#  'company': 203,
#  'resources': 204,
#  'by': 205,
#  'privacy': 206,
#  '5': 207,
#  'all': 208,
#  'medium': 209,
#  'cz': 210,
#  'servicelogin': 211,
#  'main': 212,
#  'vn': 213,
#  '80': 214,
#  'live': 215,
#  'no': 216,
#  'aol': 217,
#  'ae': 218,
#  'youtube': 219,
#  'b2': 220,
#  'go': 221,
#  'bd': 222,
#  'passive': 223,
#  'how': 224,
#  '19': 225,
#  'xyz': 226,
#  'za': 227,
#  'ir': 228,
#  'bt': 229,
#  'ar': 230,
#  'campaign': 231,
#  '178': 232,
#  'videos': 233,
#  'e6': 234,
#  'r': 235,
#  'v3': 236,
#  '18': 237,
#  'webwave': 238,
#  'b0': 239,
#  'sports': 240,
#  'forms': 241,
#  'b4': 242,
#  'help': 243,
#  'events': 244,
#  'policy': 245,
#  'solutions': 246,
#  '8a': 247,
#  'practice': 248,
#  'da': 249,
#  'ad': 250,
#  'identifier': 251,
#  'q': 252,
#  'a9': 253,
#  'free': 254,
#  'data': 255,
#  'profile': 256,
#  '7': 257,
#  'na': 258,
#  'kvadtc': 259,
#  'followup': 260,
#  '6': 261,
#  'dsh': 262,
#  '2021': 263,
#  'flowentry': 264,
#  'flowname': 265,
#  'pg': 266,
#  'webflow': 267,
#  'o': 268,
#  '2faccounts': 269,
#  'b': 270,
#  'type': 271,
#  'd7': 272,
#  'pro': 273,
#  'cat': 274,
#  '12': 275,
#  'pt': 276,
#  '11': 277,
#  'test': 278,
#  'update': 279,
#  'und': 280,
#  'instagram': 281,
#  '3f': 282,
#  'ro': 283,
#  '8': 284,
#  'author': 285,
#  'c3': 286,
#  'ec': 287,
#  'health': 288,
#  'fi': 289,
#  'post': 290,
#  '22': 291,
#  'mybluehost': 292,
#  'office': 293,
#  'webydo': 294,
#  'w': 295,
#  'categories': 296,
#  'articles': 297,
#  'from': 298,
#  'auth': 299,
#  'store': 300,
#  'life': 301,
#  'outlook': 302,
#  'review': 303,
#  'account': 304,
#  'mbr': 305,
#  'your': 306,
#  'terms': 307,
#  'godaddysites': 308,
#  'manga': 309,
#  'our': 310,
#  'redirect': 311,
#  'b5': 312,
#  'cprapid': 313,
#  'worker': 314,
#  'windows': 315,
#  'forum': 316,
#  'cloud': 317,
#  'microsoft': 318,
#  'portal': 319,
#  'a6': 320,
#  'game': 321,
#  'gr': 322,
#  'games': 323,
#  'hu': 324,
#  'sport': 325,
#  'tags': 326,
#  'cl': 327,
#  'gd': 328,
#  'public': 329,
#  'f': 330,
#  'management': 331,
#  'e8': 332,
#  'research': 333,
#  'xxx': 334,
#  'education': 335,
#  'ba': 336,
#  'weblitesignin': 337,
#  'city': 338,
#  'action': 339,
#  '17': 340,
#  'e7': 341,
#  'comments': 342,
#  'accessories': 343,
#  'secure': 344,
#  'kr': 345,
#  'jobs': 346,
#  'sign': 347,
#  'shorturl': 348,
#  'out': 349,
#  'cos': 350,
#  'global': 351,
#  'bit': 352,
#  'glitch': 353,
#  'detail': 354,
#  'linkedin': 355,
#  'one': 356,
#  'admin': 357,
#  'country': 358,
#  'tools': 359,
#  'bc': 360,
#  'dk': 361,
#  'information': 362,
#  'shtml': 363,
#  'sk': 364,
#  'brand': 365,
#  'n': 366,
#  '94': 367,
#  'center': 368,
#  'watch': 369,
#  'myqcloud': 370,
#  'guide': 371,
#  '21': 372,
#  'dlya': 373,
#  'sale': 374,
#  '99': 375,
#  'porn': 376,
#  'apps': 377,
#  'what': 378,
#  'sex': 379,
#  'y': 380,
#  'mx': 381,
#  'security': 382,
#  'e4': 383,
#  'as': 384,
#  'forums': 385,
#  'a1': 386,
#  'mobile': 387,
#  'cgi': 388,
#  'wiki': 389,
#  'click': 390,
#  'default': 391,
#  'community': 392,
#  '09': 393,
#  'a4': 394,
#  'b7': 395,
#  'ref': 396,
#  '2020': 397,
#  'football': 398,
#  'bg': 399,
#  'su': 400,
#  'digital': 401,
#  'reviews': 402,
#  '97': 403,
#  'z': 404,
#  '9': 405,
#  'client': 406,
#  'bb': 407,
#  'bf': 408,
#  '8b': 409,
#  'food': 410,
#  'cutt': 411,
#  '24': 412,
#  'il': 413,
#  'domain': 414,
#  'uploads': 415,
#  'show': 416,
#  'chapter': 417,
#  'website': 418,
#  'club': 419,
#  'az': 420,
#  'asp': 421,
#  'you': 422,
#  'we': 423,
#  'hello': 424,
#  'download': 425,
#  '2023': 426,
#  'biz': 427,
#  'a3': 428,
#  'share': 429,
#  'k': 430,
#  '89': 431,
#  'channel': 432,
#  'ukit': 433,
#  '13': 434,
#  'gb': 435,
#  'team': 436,
#  'report': 437,
#  'e9': 438,
#  '35': 439,
#  'a5': 440,
#  'board': 441,
#  'so': 442,
#  '93': 443,
#  'ne': 444,
#  'tw': 445,
#  'personal': 446,
#  'lang': 447,
#  'art': 448,
#  'sky': 449,
#  'market': 450,
#  '9c': 451,
#  'file': 452,
#  '3d': 453,
#  'series': 454,
#  'form': 455,
#  '95': 456,
#  'topic': 457,
#  'auto': 458,
#  'sa': 459,
#  'archives': 460,
#  '2fwww': 461,
#  'ap': 462,
#  'uspz': 463,
#  'et': 464,
#  'programs': 465,
#  'internet': 466,
#  'event': 467,
#  '15': 468,
#  'travel': 469,
#  'pid': 470,
#  'hubside': 471,
#  '90': 472,
#  '23': 473,
#  'images': 474,
#  'apple': 475,
#  'jpg': 476,
#  'inicio': 477,
#  '14': 478,
#  'brands': 479,
#  'case': 480,
#  'school': 481,
#  'careers': 482,
#  'example': 483,
#  '3bfollowup': 484,
#  'technology': 485,
#  'archive': 486,
#  'otziv': 487,
#  'nz': 488,
#  'host': 489,
#  'faq': 490,
#  '34': 491,
#  'text': 492,
#  'mockplus': 493,
#  'care': 494,
#  'marketing': 495,
#  'women': 496,
#  'worldairlinenews': 497,
#  'code': 498,
#  'tech': 499,
#  'student': 500,
#  'btinternet': 501,
#  'hide': 502,
#  'g': 503,
#  '3bxrealip': 504,
#  'software': 505,
#  'up': 506,
#  'member': 507,
#  'ab': 508,
#  'science': 509,
#  '98': 510,
#  'token': 511,
#  'el': 512,
#  'hr': 513,
#  'includes': 514,
#  'vigilafrica': 515,
#  'genre': 516,
#  'more': 517,
#  '26': 518,
#  'legal': 519,
#  'item': 520,
#  '08': 521,
#  'lv': 522,
#  'owa': 523,
#  'flowcode': 524,
#  'features': 525,
#  'th': 526,
#  'nav': 527,
#  '2019': 528,
#  'international': 529,
#  'dweb': 530,
#  'group': 531,
#  'press': 532,
#  'vs': 533,
#  'corporate': 534,
#  'juno': 535,
#  'get': 536,
#  'kz': 537,
#  'books': 538,
#  'ionos': 539,
#  'design': 540,
#  '134': 541,
#  'js': 542,
#  '203': 543,
#  'github': 544,
#  '232': 545,
#  'le': 546,
#  'day': 547,
#  'collection': 548,
#  '156': 549,
#  'files': 550,
#  'title': 551,
#  'interactivelogin': 552,
#  'womens': 553,
#  'gallery': 554,
#  'work': 555,
#  'server': 556,
#  'xn': 557,
#  '25': 558,
#  'customer': 559,
#  'movies': 560,
#  'play': 561,
#  'si': 562,
#  '5d': 563,
#  'region': 564,
#  'vip': 565,
#  'a2': 566,
#  'ee': 567,
#  '2c': 568,
#  'story': 569,
#  'book': 570,
#  'movie': 571,
#  'hotmail': 572,
#  'tips': 573,
#  '171': 574,
#  'car': 575,
#  'price': 576,
#  'lt': 577,
#  'payment': 578,
#  'black': 579,
#  '16': 580,
#  'kids': 581,
#  'topics': 582,
#  'state': 583,
#  'rs': 584,
#  'run': 585,
#  'homepage': 586,
#  'gitbook': 587,
#  'local': 588,
#  'respond': 589,
#  'safety': 590,
#  'program': 591,
#  'people': 592,
#  'vercel': 593,
#  'pk': 594,
#  'name': 595,
#  'error': 596,
#  'plus': 597,
#  'are': 598,
#  '3bifkv': 599,
#  'music': 600,
#  'history': 601,
#  'a0': 602,
#  '02': 603,
#  '01': 604,
#  'ce': 605,
#  'recipes': 606,
#  '9d': 607,
#  '46': 608,
#  'card': 609,
#  '207': 610,
#  'social': 611,
#  '8d': 612,
#  'verify': 613,
#  'power': 614,
#  'insurance': 615,
#  '8f': 616,
#  'yahoo': 617,
#  'inc': 618,
#  'hot': 619,
#  'der': 620,
#  'b6': 621,
#  '96': 622,
#  '3e': 623,
#  'qrco': 624,
#  'delivery': 625,
#  'un': 626,
#  'language': 627,
#  '3bpassive': 628,
#  'filter': 629,
#  '9f': 630,
#  'api': 631,
#  '27': 632,
#  'plan': 633,
#  'men': 634,
#  'use': 635,
#  'learning': 636,
#  'ws': 637,
#  'ed': 638,
#  'unknown': 639,
#  'verification': 640,
#  'netlify': 641,
#  'an': 642,
#  'partners': 643,
#  'find': 644,
#  '50': 645,
#  'sg': 646,
#  'rp': 647,
#  'protection': 648,
#  'development': 649,
#  'di': 650,
#  'details': 651,
#  'aeon': 652,
#  'credit': 653,
#  'access': 654,
#  '03': 655,
#  'ja': 656,
#  'orange': 657,
#  'script': 658,
#  'members': 659,
#  'year': 660,
#  'money': 661,
#  'themes': 662,
#  'general': 663,
#  '91': 664,
#  'amazon': 665,
#  'now': 666,
#  'browse': 667,
#  '118': 668,
#  'dhl': 669,
#  'cs': 670,
#  'ie': 671,
#  'big': 672,
#  'fuer': 673,
#  'register': 674,
#  'why': 675,
#  'family': 676,
#  'order': 677,
#  '3p0c2bt9': 678,
#  'am': 679,
#  '2018': 680,
#  'storage': 681,
#  'ads': 682,
#  'or': 683,
#  'add': 684,
#  'label': 685,
#  'eb': 686,
#  'training': 687,
#  'ai': 688,
#  '198': 689,
#  'system': 690,
#  'pc': 691,
#  'slot': 692,
#  'buy': 693,
#  'eromanga': 694,
#  'sso': 695,
#  'du': 696,
#  'pe': 697,
#  'real': 698,
#  'rt': 699,
#  'open': 700,
#  '9b': 701,
#  'exec': 702,
#  'almardoof': 703,
#  'film': 704,
#  'key': 705,
#  'answers': 706,
#  'photo': 707,
#  '05': 708,
#  'cdn': 709,
#  'fc': 710,
#  'jotform': 711,
#  'newburycafe': 712,
#  'zuza': 713,
#  'stefek': 714,
#  'szczecin': 715,
#  'career': 716,
#  'katalog': 717,
#  'energy': 718,
#  'industry': 719,
#  '1000': 720,
#  'hosting': 721,
#  '07': 722,
#  'hyperphp': 723,
#  '06': 724,
#  'job': 725,
#  'blogs': 726,
#  'can': 727,
#  'para': 728,
#  'campus': 729,
#  'national': 730,
#  'lifestyle': 731,
#  '36': 732,
#  'h': 733,
#  'rps': 734,
#  'other': 735,
#  'house': 736,
#  'courses': 737,
#  'hd': 738,
#  'del': 739,
#  'optikgeneral': 740,
#  'time': 741,
#  'entertainment': 742,
#  'special': 743,
#  'area': 744,
#  '67': 745,
#  'study': 746,
#  'die': 747,
#  '30': 748,
#  'fire': 749,
#  'connect': 750,
#  'hotel': 751,
#  'dt': 752,
#  'int': 753,
#  'stories': 754,
#  'log': 755,
#  '128': 756,
#  'des': 757,
#  'om': 758,
#  'section': 759,
#  'bodis': 760,
#  'release': 761,
#  'cms': 762,
#  'macros': 763,
#  '9a': 764,
#  'alkhudharigroup': 765,
#  'beauty': 766,
#  'podcast': 767,
#  '04': 768,
#  'project': 769,
#  'po': 770,
#  'keepo': 771,
#  'covid': 772,
#  'cps': 773,
#  'partner': 774,
#  '200': 775,
#  'soft': 776,
#  'financial': 777,
#  'conditions': 778,
#  'clothing': 779,
#  '159': 780,
#  'smart': 781,
#  'jsp': 782,
#  'track': 783,
#  'star': 784,
#  'water': 785,
#  'print': 786,
#  'latest': 787,
#  'mens': 788,
#  'first': 789,
#  'usa': 790,
#  'fun': 791,
#  '37': 792,
#  'china': 793,
#  'glifwebsignin': 794,
#  'ef': 795,
#  'week': 796,
#  'les': 797,
#  '45': 798,
#  'bank': 799,
#  'ha': 800,
#  'law': 801,
#  'projects': 802,
#  'who': 803,
#  'popular': 804,
#  'pinterest': 805,
#  'flow': 806,
#  'off': 807,
#  'ng': 808,
#  'library': 809,
#  'air': 810,
#  'audio': 811,
#  'kvsecure': 812,
#  'dvosplt': 813,
#  'locations': 814,
#  'learn': 815,
#  'yes': 816,
#  'well': 817,
#  'preview': 818,
#  'screen': 819,
#  'unexpected': 820,
#  '2017': 821,
#  'ui': 822,
#  '226': 823,
#  '153': 824,
#  'full': 825,
#  'date': 826,
#  'europe': 827,
#  'node': 828,
#  '100': 829,
#  'noticias': 830,
#  'reagan': 831,
#  '129': 832,
#  'myportfolio': 833,
#  'college': 834,
#  'reload': 835,
#  'wordpress': 836,
#  'university': 837,
#  'abuse': 838,
#  'chat': 839,
#  'finance': 840,
#  'desktop': 841,
#  'old': 842,
#  'love': 843,
#  'india': 844,
#  'tube': 845,
#  'english': 846,
#  'academics': 847,
#  'culture': 848,
#  '4462653': 849,
#  'cars': 850,
#  '29': 851,
#  'platform': 852,
#  'hk': 853,
#  'tracking': 854,
#  'theme': 855,
#  'alt': 856,
#  'im': 857,
#  'term': 858,
#  'baby': 859,
#  'sort': 860,
#  'taplink': 861,
#  'aruba': 862,
#  '56': 863,
#  'systems': 864,
#  'fbclid': 865,
#  'comment': 866,
#  'sustainability': 867,
#  'menu': 868,
#  'hotels': 869,
#  'students': 870,
#  '9e': 871,
#  'meta': 872,
#  'authorize': 873,
#  'white': 874,
#  'index2': 875,
#  'banner': 876,
#  've': 877,
#  're': 878,
#  'government': 879,
#  'cards': 880,
#  'magazine': 881,
#  'this': 882,
#  'today': 883,
#  'netflix': 884,
#  'south': 885,
#  'hl': 886,
#  'android': 887,
#  'links': 888,
#  'cfm': 889,
#  'responsepage': 890,
#  'class': 891,
#  'weather': 892,
#  '41': 893,
#  'bin': 894,
#  'doc': 895,
#  'ph': 896,
#  'plugins': 897,
#  'gclid': 898,
#  'al': 899,
#  'status': 900,
#  'netzero': 901,
#  'sitemap': 902,
#  'tickets': 903,
#  'loans': 904,
#  'map': 905,
#  '8e': 906,
#  '60': 907,
#  'reports': 908,
#  'sharer': 909,
#  'industries': 910,
#  'season': 911,
#  'high': 912,
#  'calculator': 913,
#  'document': 914,
#  'visit': 915,
#  'hp': 916,
#  'footer': 917,
#  '181': 918,
#  'location': 919,
#  'ueber': 920,
#  'releases': 921,
#  'cancer': 922,
#  'arts': 923,
#  '2016': 924,
#  'space': 925,
#  'formstack': 926,
#  'filename': 927,
#  'san': 928,
#  'c5': 929,
#  'check': 930,
#  'banking': 931,
#  'uspo': 932,
#  'rd': 933,
#  'not': 934,
#  'united': 935,
#  'models': 936,
#  'calendar': 937,
#  'equipment': 938,
#  'ff': 939,
#  'entry': 940,
#  'red': 941,
#  'src': 942,
#  '2010': 943,
#  'chrome': 944,
#  '231': 945,
#  'photos': 946,
#  'things': 947,
#  'gifts': 948,
#  'voddetail': 949,
#  'admissions': 950,
#  'academic': 951,
#  'feed': 952,
#  'que': 953,
#  'load': 954,
#  'tw1': 955,
#  'gift': 956,
#  'users': 957,
#  'jemi': 958,
#  'viewform': 959,
#  'wallet': 960,
#  '109': 961,
#  'guides': 962,
#  '28': 963,
#  'uni': 964,
#  'man': 965,
#  'demo': 966,
#  'radio': 967,
#  'vk': 968,
#  'transport': 969,
#  'non': 970,
#  '1318439371': 971,
#  'trackconfirmaction': 972,
#  'sales': 973,
#  'bbs': 974,
#  'make': 975,
#  'directory': 976,
#  'casino': 977,
#  'embed': 978,
#  '185': 979,
#  'dreamwp': 980,
#  'oferta': 981,
#  'landing': 982,
#  '245': 983,
#  'trade': 984,
#  '00': 985,
#  'medical': 986,
#  'tax': 987,
#  'sviluppo': 988,
#  'zh': 989,
#  '103': 990,
#  'maps': 991,
#  'asia': 992,
#  '167': 993,
#  'portfolio': 994,
#  'hub': 995,
#  'c2': 996,
#  'e2': 997,
#  'see': 998,
#  'parts': 999,
#  'land': 1000,
#  ...}

# %%
tokenizer_word_json = tokenizer_word_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/TUGAS AKHIR/Notebook/URL/Tokenizer/new_tokenizer_word_level.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_word_json))
