# %% [markdown]
# # 🎯 **Step 0: Import Library**
# ---

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🎯 **Step 1: Load Dataset**
# ---

# %% [markdown]
# ## ✨ 1.3 - Dataset PHISHTANK

# %%
path = '/content/drive/MyDrive/TUGAS AKHIR/Notebook/Dataset/URL/new_phishtank.csv'

df_url_pt = pd.read_csv(path)

df_url_pt.head()
# Out:
#                                                  URL  Category
# 0                  https://ats-cool-site.webflow.io/  phishing
# 1  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 2  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 3                      https://m8vqz27f.square.site/  phishing
# 4  https://docs.google.com/presentation/d/e/2PACX...  phishing

# %% [markdown]
# ## ✨ 1.5 - Dataset OSF

# %%
path = '/content/drive/MyDrive/TUGAS AKHIR/Notebook/Dataset/URL/new_osf.csv'

df_url_osf_nonphishing = pd.read_csv(path)

df_url_osf_nonphishing.head()
# Out:
#                                                  URL      Category
# 0  https://skinnyms.com/category/recipes/meal-typ...  non-phishing
# 1     https://my.autoscout24.ch/de/fahrzeugbewertung  non-phishing
# 2  https://www.isba.org/cle/path?pathpage=/isba/c...  non-phishing
# 3                        https://www.viator.com/news  non-phishing
# 4  https://www.timberland.de/shop/de/tbl-de/damen...  non-phishing

# %% [markdown]
# # 🎯 **Step 2: Preprocess Dataset**
# ---

# %% [markdown]
# ## ✨ 2.1 - Check the amount of data

# %% [markdown]
# ### 📫 2.1.1 - Phishing

# %%
phishing3 = df_url_pt[df_url_pt['Category'] == 'phishing']

# %%
len(phishing3)
# Out:
# 50000

# %%
df_phishing = phishing3

df_phishing.head()
# Out:
#                                                  URL  Category
# 0                  https://ats-cool-site.webflow.io/  phishing
# 1  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 2  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 3                      https://m8vqz27f.square.site/  phishing
# 4  https://docs.google.com/presentation/d/e/2PACX...  phishing

# %% [markdown]
# ### 📫 2.1.2 - Non-phishing

# %%
non_phishing3 = df_url_osf_nonphishing[df_url_osf_nonphishing['Category'] == 'non-phishing']

# %%
len(non_phishing3)
# Out:
# 50000

# %%
df_nonphishing = non_phishing3

df_nonphishing.head()
# Out:
#                                                  URL      Category
# 0  https://skinnyms.com/category/recipes/meal-typ...  non-phishing
# 1     https://my.autoscout24.ch/de/fahrzeugbewertung  non-phishing
# 2  https://www.isba.org/cle/path?pathpage=/isba/c...  non-phishing
# 3                        https://www.viator.com/news  non-phishing
# 4  https://www.timberland.de/shop/de/tbl-de/damen...  non-phishing

# %% [markdown]
# ## ✨ 2.2 - Check and remove duplicate data

# %% [markdown]
# ### 📫 2.2.1 - Phishing

# %%
df_phishing.duplicated().sum()
# Out:
# 0

# %%
# df_phishing.drop_duplicates(keep='first', inplace=True)

# %%
# df_phishing.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 📫 2.2.2 - Non-phishing

# %%
df_nonphishing.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## ✨ 2.3 - Balance the amount of data for each category

# %%
# len(df_phishing), len(df_nonphishing)
# Out:
# (50000, 50000)

# %% [markdown]
# # 🎯 **Step 3: Combining Into One Dataset**
#
# ---

# %%
df_url = pd.concat([df_phishing, df_nonphishing])

df_url.head()
# Out:
#                                                  URL  Category
# 0                  https://ats-cool-site.webflow.io/  phishing
# 1  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 2  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 3                      https://m8vqz27f.square.site/  phishing
# 4  https://docs.google.com/presentation/d/e/2PACX...  phishing

# %% [markdown]
# # 🎯 **Step 4: Save the Dataset**
#
# ---

# %%
file_path = '/content/drive/MyDrive/TUGAS AKHIR/Notebook/Dataset/URL/new_url.csv'

df_url.to_csv(file_path, index=False)

# %%
df_url.duplicated().sum()
# Out:
# 0
