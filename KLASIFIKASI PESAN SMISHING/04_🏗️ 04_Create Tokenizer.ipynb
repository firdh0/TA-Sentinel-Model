# %% [markdown]
# # 📢 File explanation!!

# %% [markdown]
# ...........

# %% [markdown]
# # 🎯 **Step 0: Import library**
# ---

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import json

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
plt.style.use('seaborn')
# Out:
# <ipython-input-2-4a43041a1d49>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🎯 **Step 1: Load Dataset**
# ---

# %%
path = '/content/drive/MyDrive/TUGAS AKHIR/Dataset/PESAN TEKS/df_message_after_preprocessing.csv'

df_message = pd.read_csv(path)

df_message.head()
# Out:
#                                                 Data  Category  \
# 0  PEMBERITAHUAN RESMI\n\nAnda Terdaftar Sebagai ...  phishing
# 1  SELAMAT ANDA TERPILIH SEBAGAI PENERIMA DANA BA...  phishing
# 2  Langsung dapat ekstra 100% di depan\nUntuk pen...  phishing
# 3  PEMBERITAHUAN RESMI\nSelamat ANDA TERPILIH Seb...  phishing
# 4  Gapai impianmu dsni, Ksmpatan emas\ninfo pst j...  phishing
#
#                                        clean_message  \
# 0  ['pemberitahuan', 'resmi', 'daftar', 'bagai', ...
# 1  ['selamat', 'pilih', 'bagai', 'terima', 'dana'...
# 2  ['langsung', 'ekstra', '100', 'depan', 'datang...
# 3  ['pemberitahuan', 'resmi', 'selamat', 'pilih',...
# 4  ['gapai', 'impi', 'sini', 'ksmpatan', 'emas', ...
#
#                               clean_message_sentence
# 0  pemberitahuan resmi daftar bagai terima dana b...
# 1  selamat pilih bagai terima dana bantu bpjs pus...
# 2  langsung ekstra 100 depan datang barugak pakai...
# 3  pemberitahuan resmi selamat pilih bagai terima...
# 4  gapai impi sini ksmpatan emas informasi joss a...

# %% [markdown]
# # 🎯 **Step 2: Split data into feature and label**
# ---

# %%
X = df_message['clean_message_sentence']

y = df_message['Category']

# %% [markdown]
# # 🎯 **Step 3: Processing X**
# ---

# %% [markdown]
# ## ✨ 3.1 - Create Char Level Corpus for Tokenizing and Padding

# %%
X = [str(text) for text in X]

tokenizer_char_level = Tokenizer(num_words=None, oov_token='<OOV>', char_level=True)
tokenizer_char_level.fit_on_texts(X)
# X_sequences_char_level = tokenizer_char_level.texts_to_sequences(X)
# X_padded_char_level = pad_sequences(X_sequences_char_level, padding='post', truncating='post', maxlen=2000)

# # Build vocabulary
# vocab_size_char_level = len(tokenizer_char_level.word_index) + 1

# X_padded_char_level

# %%
len(tokenizer_char_level.word_index)
# Out:
# 39

# %%
tokenizer_char_level.word_index
# Out:
# {'<OOV>': 1,
#  ' ': 2,
#  'a': 3,
#  'i': 4,
#  'n': 5,
#  't': 6,
#  'e': 7,
#  's': 8,
#  'r': 9,
#  'u': 10,
#  'k': 11,
#  'm': 12,
#  'l': 13,
#  'h': 14,
#  'p': 15,
#  'o': 16,
#  'g': 17,
#  'b': 18,
#  'd': 19,
#  '0': 20,
#  'j': 21,
#  'w': 22,
#  'c': 23,
#  'y': 24,
#  'f': 25,
#  '2': 26,
#  '1': 27,
#  '5': 28,
#  '3': 29,
#  '8': 30,
#  'v': 31,
#  '7': 32,
#  '4': 33,
#  '6': 34,
#  '9': 35,
#  'z': 36,
#  'x': 37,
#  'q': 38,
#  '-': 39}

# %%
tokenizer_char_json = tokenizer_char_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/TUGAS AKHIR/Notebook/PESAN TEKS/Tokenizer/tokenizer_char_level.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_char_json))

# %% [markdown]
# ## ✨ 3.1 - Create Word Level Corpus for Tokenizing and Padding

# %%
tokenizer_word_level = Tokenizer(num_words=None, oov_token='<OOV>')
tokenizer_word_level.fit_on_texts(X)
# X_sequences_word_level = tokenizer_word_level.texts_to_sequences(X)
# X_padded_word_level = pad_sequences(X_sequences_word_level, padding='post', truncating='post', maxlen=2000)

# # Build vocabulary
# vocab_size_word_level = len(tokenizer_word_level.word_index) + 1

# X_padded_word_level

# %%
len(tokenizer_word_level.word_index)
# Out:
# 3309

# %%
tokenizer_word_level.word_index
# Out:
# {'<OOV>': 1,
#  '000': 2,
#  'whatsapp': 3,
#  'tidak': 4,
#  'kerja': 5,
#  'terima': 6,
#  'kak': 7,
#  'hadiah': 8,
#  'shopee': 9,
#  'rupiah': 10,
#  'nomor': 11,
#  'taut': 12,
#  'hari': 13,
#  'informasi': 14,
#  'kirim': 15,
#  'waktu': 16,
#  'daftar': 17,
#  'bagai': 18,
#  'sila': 19,
#  'selamat': 20,
#  'iya': 21,
#  'ikut': 22,
#  'lalu': 23,
#  'pilih': 24,
#  'dana': 25,
#  'kamu': 26,
#  'klik': 27,
#  'indonesia': 28,
#  'hubung': 29,
#  'bantu': 30,
#  'lebih': 31,
#  'menang': 32,
#  'mohon': 33,
#  'kode': 34,
#  'kasih': 35,
#  'lanjut': 36,
#  'hingga': 37,
#  'mas': 38,
#  'juta': 39,
#  'baru': 40,
#  'besar': 41,
#  'sama': 42,
#  'atas': 43,
#  'jadi': 44,
#  'langsung': 45,
#  'segera': 46,
#  'cara': 47,
#  '1': 48,
#  '2': 49,
#  'tambah': 50,
#  'tugas': 51,
#  'program': 52,
#  'gratis': 53,
#  'tarik': 54,
#  'halo': 55,
#  'akun': 56,
#  'kakak': 57,
#  'kalau': 58,
#  'paruh': 59,
#  'sempat': 60,
#  'bawah': 61,
#  'tahun': 62,
#  'laku': 63,
#  'baik': 64,
#  'sekarang': 65,
#  'bonus': 66,
#  'apa': 67,
#  'online': 68,
#  'biaya': 69,
#  'sangat': 70,
#  'maaf': 71,
#  'pt': 72,
#  'bayar': 73,
#  'beri': 74,
#  'jangan': 75,
#  'gabung': 76,
#  '5': 77,
#  'bank': 78,
#  'transaksi': 79,
#  'mulai': 80,
#  'buka': 81,
#  'tim': 82,
#  'salah': 83,
#  'isi': 84,
#  'ambil': 85,
#  'balas': 86,
#  'ai': 87,
#  'jawab': 88,
#  'mau': 89,
#  'aplikasi': 90,
#  'klaim': 91,
#  'hasil': 92,
#  'satu': 93,
#  'pinjam': 94,
#  'id': 95,
#  'uang': 96,
#  '30': 97,
#  'bulan': 98,
#  'mudah': 99,
#  'bpjs': 100,
#  'voucher': 101,
#  'tanya': 102,
#  'sedang': 103,
#  'konfirmasi': 104,
#  'jam': 105,
#  'tiap': 106,
#  'sebut': 107,
#  'latih': 108,
#  'pin': 109,
#  'semua': 110,
#  'minta': 111,
#  'gaji': 112,
#  'layan': 113,
#  'hai': 114,
#  'resmi': 115,
#  'butuh': 116,
#  'tunai': 117,
#  'pakai': 118,
#  'sini': 119,
#  'promo': 120,
#  'pesan': 121,
#  '2024': 122,
#  'kamp': 123,
#  'cari': 124,
#  'syarat': 125,
#  '3': 126,
#  'izin': 127,
#  'perlu': 128,
#  'akhir': 129,
#  '100': 130,
#  'tuju': 131,
#  'tanggal': 132,
#  'selesai': 133,
#  'siap': 134,
#  'ajar': 135,
#  'milik': 136,
#  'wib': 137,
#  'masuk': 138,
#  'depan': 139,
#  'usia': 140,
#  'tawar': 141,
#  'lihat': 142,
#  'temu': 143,
#  'buat': 144,
#  'nya': 145,
#  'nama': 146,
#  'sms': 147,
#  'kabar': 148,
#  'proses': 149,
#  'umum': 150,
#  'kelas': 151,
#  'datang': 152,
#  'rekening': 153,
#  '10': 154,
#  'ribu': 155,
#  'sedia': 156,
#  'cek': 157,
#  'tahu': 158,
#  'kunjung': 159,
#  '50': 160,
#  'surat': 161,
#  'aman': 162,
#  'mbak': 163,
#  'untung': 164,
#  'malam': 165,
#  'coba': 166,
#  'pukul': 167,
#  'ibu': 168,
#  'harap': 169,
#  'nasabah': 170,
#  'bapak': 171,
#  'video': 172,
#  'nila': 173,
#  'sih': 174,
#  'posisi': 175,
#  'tunggu': 176,
#  '4': 177,
#  'teman': 178,
#  'penting': 179,
#  'ganggu': 180,
#  'tinggal': 181,
#  'bagaimana': 182,
#  'belanja': 183,
#  'orang': 184,
#  'sesuai': 185,
#  'telegram': 186,
#  'pusat': 187,
#  'lama': 188,
#  'hadir': 189,
#  'hormat': 190,
#  'lewat': 191,
#  '20': 192,
#  'menit': 193,
#  'bri': 194,
#  'langgan': 195,
#  'lowong': 196,
#  'inc': 197,
#  'akses': 198,
#  'lengkap': 199,
#  'tarif': 200,
#  'firdho': 201,
#  'batas': 202,
#  'ponsel': 203,
#  'anak': 204,
#  'senang': 205,
#  'admin': 206,
#  'pulih': 207,
#  'asuransi': 208,
#  'undi': 209,
#  'detail': 210,
#  'sehat': 211,
#  'ahmad': 212,
#  'tokopedia': 213,
#  '500': 214,
#  'assalamualaikum': 215,
#  'perhati': 216,
#  'spesial': 217,
#  'tingkat': 218,
#  'telkomsel': 219,
#  'moga': 220,
#  '11': 221,
#  'me': 222,
#  'ubah': 223,
#  'postingan': 224,
#  'per': 225,
#  'operator': 226,
#  'www': 227,
#  'ucap': 228,
#  'rp2': 229,
#  'beberapa': 230,
#  'jelas': 231,
#  'cepat': 232,
#  'game': 233,
#  'com': 234,
#  'kenal': 235,
#  'formulir': 236,
#  'lupa': 237,
#  'siang': 238,
#  'kantor': 239,
#  'customer': 240,
#  'siapa': 241,
#  'data': 242,
#  '23': 243,
#  '60': 244,
#  'proyek': 245,
#  'zhar': 246,
#  'email': 247,
#  'yuk': 248,
#  '00': 249,
#  'hidup': 250,
#  'cabang': 251,
#  'gembira': 252,
#  '2018': 253,
#  'muhammad': 254,
#  'situs': 255,
#  '22': 256,
#  'entertainment': 257,
#  'harga': 258,
#  'undang': 259,
#  'produk': 260,
#  'mana': 261,
#  'like': 262,
#  'kontak': 263,
#  'tempat': 264,
#  'aktif': 265,
#  'berita': 266,
#  'salam': 267,
#  'kan': 268,
#  'express': 269,
#  '75': 270,
#  'wajib': 271,
#  'wanita': 272,
#  'minimal': 273,
#  'diri': 274,
#  'pulsa': 275,
#  'rans': 276,
#  'nilai': 277,
#  '2023': 278,
#  'banyak': 279,
#  'simpan': 280,
#  'kena': 281,
#  'angkat': 282,
#  'via': 283,
#  '200': 284,
#  'siswa': 285,
#  'ganti': 286,
#  'kuis': 287,
#  'minggu': 288,
#  'punya': 289,
#  'time': 290,
#  'barang': 291,
#  'group': 292,
#  '6': 293,
#  'raffi': 294,
#  'kait': 295,
#  'soal': 296,
#  'paling': 297,
#  'angka': 298,
#  'shopeepay': 299,
#  'part': 300,
#  'creative': 301,
#  'pegawai': 302,
#  'indofood': 303,
#  'driver': 304,
#  'nagita': 305,
#  'slavina': 306,
#  'internet': 307,
#  'giveaway': 308,
#  'gigi': 309,
#  'dulu': 310,
#  'grup': 311,
#  'rumah': 312,
#  'otomatis': 313,
#  'manajer': 314,
#  'fasilitas': 315,
#  'polisi': 316,
#  'rafi': 317,
#  'benar': 318,
#  'catat': 319,
#  'domisili': 320,
#  'bangsa': 321,
#  'marketing': 322,
#  'alami': 323,
#  'perintah': 324,
#  'kasir': 325,
#  'production': 326,
#  'layar': 327,
#  'aku': 328,
#  'kemarin': 329,
#  'tes': 330,
#  'big': 331,
#  'sale': 332,
#  'negara': 333,
#  'tetap': 334,
#  'harta': 335,
#  'sebentar': 336,
#  'service': 337,
#  'subscribe': 338,
#  'beku': 339,
#  'pria': 340,
#  'smk': 341,
#  'makan': 342,
#  'dagang': 343,
#  'bukti': 344,
#  'mungkin': 345,
#  'nikmat': 346,
#  'pagi': 347,
#  'kustiawan': 348,
#  'e': 349,
#  'pihak': 350,
#  'lapor': 351,
#  'putus': 352,
#  'beli': 353,
#  'karyawan': 354,
#  'unduh': 355,
#  'saran': 356,
#  'spbu': 357,
#  '185': 358,
#  '45': 359,
#  'urus': 360,
#  'gunawan': 361,
#  'tangkap': 362,
#  'arti': 363,
#  'academy': 364,
#  'seleksi': 365,
#  'member': 366,
#  'departemen': 367,
#  'sdm': 368,
#  'kapan': 369,
#  'biasa': 370,
#  'kali': 371,
#  'berkah': 372,
#  'jnt': 373,
#  'survei': 374,
#  'cukup': 375,
#  'jalan': 376,
#  'tekan': 377,
#  'kurang': 378,
#  'terus': 379,
#  '21': 380,
#  'malaysia': 381,
#  'aktivitas': 382,
#  'ayo': 383,
#  'langgar': 384,
#  'alamat': 385,
#  'ingat': 386,
#  'besok': 387,
#  'materi': 388,
#  'tahap': 389,
#  'usaha': 390,
#  'percaya': 391,
#  'hapus': 392,
#  'hak': 393,
#  'seluruh': 394,
#  'job': 395,
#  'biar': 396,
#  'rasa': 397,
#  'suka': 398,
#  'baca': 399,
#  'capai': 400,
#  'tagih': 401,
#  'permisi': 402,
#  'temanteman': 403,
#  'on': 404,
#  'lms': 405,
#  'dasar': 406,
#  'pertama': 407,
#  'cashback': 408,
#  'google': 409,
#  'kalian': 410,
#  'umur': 411,
#  'chat': 412,
#  'bukan': 413,
#  'peluang': 414,
#  'bu': 415,
#  'sendiri': 416,
#  'beasiswa': 417,
#  'jumat': 418,
#  'zoom': 419,
#  'pas': 420,
#  'pemberitahuan': 421,
#  '50jt': 422,
#  'ramadhan': 423,
#  'curiga': 424,
#  'hilang': 425,
#  'lulus': 426,
#  'media': 427,
#  'blogspot': 428,
#  'sederhana': 429,
#  'laksana': 430,
#  'bos': 431,
#  'setia': 432,
#  'whatsapp2018ku': 433,
#  'hadap': 434,
#  'tabung': 435,
#  'masalah': 436,
#  '15': 437,
#  'bahasa': 438,
#  'berapa': 439,
#  'maret': 440,
#  'sesi': 441,
#  'nah': 442,
#  'paket': 443,
#  'daerah': 444,
#  'lembur': 445,
#  'syahnaz': 446,
#  'rendy': 447,
#  '6283830991389': 448,
#  '6287833087356': 449,
#  'anggota': 450,
#  'input': 451,
#  'periksa': 452,
#  'diskon': 453,
#  'sore': 454,
#  'mahasiswa': 455,
#  '59': 456,
#  'laptop': 457,
#  'responden': 458,
#  'pindah': 459,
#  'pasar': 460,
#  'update': 461,
#  'periode': 462,
#  'panjang': 463,
#  'asli': 464,
#  'dekat': 465,
#  'manfaat': 466,
#  'awal': 467,
#  'istimewa': 468,
#  'tadi': 469,
#  'campus': 470,
#  'rabu': 471,
#  'skill': 472,
#  'meni': 473,
#  'keluarga': 474,
#  'kuasa': 475,
#  'tulis': 476,
#  'helper': 477,
#  'ob': 478,
#  'muat': 479,
#  'blt': 480,
#  'el': 481,
#  'nino': 482,
#  'selalu': 483,
#  'jual': 484,
#  'komunikasi': 485,
#  'khusus': 486,
#  'kelompok': 487,
#  'kata': 488,
#  'ketik': 489,
#  'bahagia': 490,
#  'kendala': 491,
#  'antri': 492,
#  'verifikasi': 493,
#  'rugi': 494,
#  'pabrik': 495,
#  'tutup': 496,
#  'penuh': 497,
#  'paham': 498,
#  'pak': 499,
#  '175': 500,
#  'jangka': 501,
#  'upah': 502,
#  'calon': 503,
#  'utama': 504,
#  'alam': 505,
#  'connector': 506,
#  '9': 507,
#  'memang': 508,
#  'drs': 509,
#  'net': 510,
#  'masa': 511,
#  'asal': 512,
#  'bawa': 513,
#  'partisipasi': 514,
#  'fleksibel': 515,
#  'kartu': 516,
#  'kerjasamanya': 517,
#  'rp3': 518,
#  '19': 519,
#  'derajat': 520,
#  'bongkar': 521,
#  'seragam': 522,
#  'kartap': 523,
#  'rp1': 524,
#  'durasi': 525,
#  'limit': 526,
#  'habis': 527,
#  'profesional': 528,
#  'acak': 529,
#  'luang': 530,
#  'kemudian': 531,
#  'binar': 532,
#  'bimits': 533,
#  '0': 534,
#  '601172206138': 535,
#  '082347653789': 536,
#  'tanggung': 537,
#  'pithikos': 538,
#  'chevron': 539,
#  'warga': 540,
#  'maksud': 541,
#  '24': 542,
#  'fatima': 543,
#  'direktur': 544,
#  'ndah': 545,
#  'amel': 546,
#  'accurate': 547,
#  'youtube': 548,
#  'dnid0120': 549,
#  'bunga': 550,
#  '04': 551,
#  'play': 552,
#  'ad25md47': 553,
#  'nyata': 554,
#  '02591234': 555,
#  'melisa': 556,
#  'pertamina': 557,
#  '400': 558,
#  'saldo': 559,
#  '300k': 560,
#  'tiktok': 561,
#  'permata': 562,
#  'agun': 563,
#  '5wre7w89': 564,
#  'xl': 565,
#  'three': 566,
#  'indosat': 567,
#  'axis': 568,
#  'smartfren': 569,
#  'chintya': 570,
#  'baim': 571,
#  'kenzo': 572,
#  '085963148544': 573,
#  'alfamart': 574,
#  'foto': 575,
#  '2547afr': 576,
#  'indra': 577,
#  '085796568819': 578,
#  'hepi': 579,
#  'tuuh2714w': 580,
#  '082344957567': 581,
#  '017': 582,
#  'xviii': 583,
#  'wa05': 584,
#  'trans7': 585,
#  '25a477': 586,
#  'banking': 587,
#  'unlimited': 588,
#  'jumlah': 589,
#  'maksimal': 590,
#  'indomaret': 591,
#  'rp200': 592,
#  'ulang': 593,
#  'april': 594,
#  'live': 595,
#  'tementemen': 596,
#  'kakakkakak': 597,
#  'ta': 598,
#  'tangga': 599,
#  'thailand': 600,
#  '2360': 601,
#  'minat': 602,
#  'makin': 603,
#  'rismafauzia': 604,
#  'a': 605,
#  'florence': 606,
#  'sandra': 607,
#  'inggris': 608,
#  'hati': 609,
#  '17': 610,
#  'kaget': 611,
#  'cuma': 612,
#  'ij4t547': 613,
#  'staff': 614,
#  'komisi': 615,
#  'suci': 616,
#  '4515': 617,
#  'jenis': 618,
#  'nyaman': 619,
#  'tipu': 620,
#  'unik': 621,
#  'tari': 622,
#  'kok': 623,
#  'rupa': 624,
#  'rp10': 625,
#  'pemrosesan': 626,
#  '081527861399': 627,
#  'wong': 628,
#  'webinar': 629,
#  'sabtu': 630,
#  'oiya': 631,
#  'cicil': 632,
#  'locked': 633,
#  'bp2279js': 634,
#  'edi': 635,
#  'rezky': 636,
#  'jerman': 637,
#  'amirah': 638,
#  'sabar': 639,
#  'd3': 640,
#  'kriteria': 641,
#  '29': 642,
#  'kreatif': 643,
#  'sekali': 644,
#  '3515': 645,
#  'code': 646,
#  'cocok': 647,
#  'memberitahu': 648,
#  'ragu': 649,
#  'sambut': 650,
#  'bicara': 651,
#  'kumpul': 652,
#  'pernah': 653,
#  'jaga': 654,
#  'karier': 655,
#  'deh': 656,
#  'mastering': 657,
#  'kuliah': 658,
#  'karir': 659,
#  'misal': 660,
#  'wakil': 661,
#  '6283131737177': 662,
#  'impi': 663,
#  'lambat': 664,
#  'hermawan': 665,
#  'tiba': 666,
#  'instagram': 667,
#  'lokasi': 668,
#  'versi': 669,
#  'suami': 670,
#  'seluler': 671,
#  'syaratsyarat': 672,
#  's1': 673,
#  'jujur': 674,
#  'viral': 675,
#  'sosial': 676,
#  'sobat': 677,
#  'keranjang': 678,
#  'terang': 679,
#  'sponsor': 680,
#  'eksklusif': 681,
#  'balik': 682,
#  'ketidaknyamanan': 683,
#  'transfer': 684,
#  'semangat': 685,
#  'handphone': 686,
#  '8': 687,
#  'mu': 688,
#  'februari': 689,
#  'kursus': 690,
#  'hacktiv8': 691,
#  'oke': 692,
#  'api': 693,
#  'prosedur': 694,
#  'muh': 695,
#  'tbk': 696,
#  'istri': 697,
#  'merek': 698,
#  'lolos': 699,
#  'yth': 700,
#  'hanoi': 701,
#  'bensin': 702,
#  'pokok': 703,
#  '30gb': 704,
#  '7': 705,
#  'samping': 706,
#  '150': 707,
#  'apabila': 708,
#  'telepon': 709,
#  'acara': 710,
#  'promosi': 711,
#  'info': 712,
#  'aju': 713,
#  'bidang': 714,
#  '1740': 715,
#  'januari': 716,
#  '12': 717,
#  'magang': 718,
#  '62': 719,
#  'putri': 720,
#  'ppt': 721,
#  'wkwkwkwk': 722,
#  'pens': 723,
#  'ycapit': 724,
#  'bakri': 725,
#  'msi': 726,
#  'provinsi': 727,
#  'emas': 728,
#  'x500': 729,
#  '1700': 730,
#  'ind': 731,
#  'saye': 732,
#  'staffendah': 733,
#  'rp15': 734,
#  'target': 735,
#  'kontrak': 736,
#  'brlpoin': 737,
#  'pom': 738,
#  'security': 739,
#  'cair': 740,
#  'shopeecod1111': 741,
#  'si': 742,
#  'wkb': 743,
#  'anggraeny': 744,
#  'adrian': 745,
#  'gvy2547hd': 746,
#  'wa75jt': 747,
#  'alat': 748,
#  'dll259779': 749,
#  '628': 750,
#  'waspada': 751,
#  'baharu': 752,
#  'digital': 753,
#  'hp': 754,
#  'keluar': 755,
#  'ringan': 756,
#  'haloo': 757,
#  'ajak': 758,
#  'komunitas': 759,
#  'final': 760,
#  'mobil': 761,
#  'hitung': 762,
#  'intake': 763,
#  'kamis': 764,
#  'bingung': 765,
#  'bikin': 766,
#  'bakal': 767,
#  'python': 768,
#  'qna': 769,
#  'bangkit': 770,
#  'okto': 771,
#  'cher': 772,
#  'ekstra': 773,
#  'puncak': 774,
#  'pulang': 775,
#  'rencana': 776,
#  'tindak': 777,
#  'blokir': 778,
#  'pungut': 779,
#  'hemat': 780,
#  'kece': 781,
#  'syur': 782,
#  'full': 783,
#  'wabarakatuh': 784,
#  '80': 785,
#  'office': 786,
#  'raih': 787,
#  'ikan': 788,
#  'tera': 789,
#  'deposit': 790,
#  'jamin': 791,
#  'sana': 792,
#  'langkah': 793,
#  'digit': 794,
#  'smsnya': 795,
#  'tenaga': 796,
#  '1020': 797,
#  'tombol': 798,
#  'opsi': 799,
#  'upa': 800,
#  'deteksi': 801,
#  'bangun': 802,
#  'tonton': 803,
#  '800': 804,
#  '6281226558830': 805,
#  'surabaya': 806,
#  'mei': 807,
#  'admission': 808,
#  'biru': 809,
#  'by': 810,
#  'ruangguru': 811,
#  'test': 812,
#  'ml': 813,
#  'ops': 814,
#  'nih': 815,
#  'mandiri': 816,
#  'suhu': 817,
#  'betul': 818,
#  'presentasi': 819,
#  'model': 820,
#  'tidur': 821,
#  'kos': 822,
#  'lab': 823,
#  'lapakcuan': 824,
#  'special': 825,
#  'alas': 826,
#  'sakit': 827,
#  '40': 828,
#  'mampu': 829,
#  'team': 830,
#  'sebar': 831,
#  'gesit': 832,
#  'potong': 833,
#  'pandu': 834,
#  'dukung': 835,
#  'investasi': 836,
#  'bebas': 837,
#  'hello': 838,
#  'hangat': 839,
#  'kisar': 840,
#  'platform': 841,
#  'bahkan': 842,
#  'web': 843,
#  'didik': 844,
#  'rekam': 845,
#  'giur': 846,
#  'tegur': 847,
#  'bandung': 848,
#  '18': 849,
#  'jakarta': 850,
#  'early': 851,
#  'loh': 852,
#  'career': 853,
#  'teknologi': 854,
#  'jadian24': 855,
#  'discord': 856,
#  'post': 857,
#  'learning': 858,
#  'pemrograman': 859,
#  'wisuda': 860,
#  'panggil': 861,
#  'error': 862,
#  'beda': 863,
#  'dho': 864,
#  'eh': 865,
#  'profil': 866,
#  'robot': 867,
#  'thermostat': 868,
#  'panas': 869,
#  'setrika': 870,
#  'listrik': 871,
#  'wkwkwk': 872,
#  'kalibrasi': 873,
#  'bohong': 874,
#  'ayah': 875,
#  'dunia': 876,
#  'bekal': 877,
#  'senggang': 878,
#  'jobsite': 879,
#  'wajar': 880,
#  'riwayat': 881,
#  'lamar': 882,
#  'bagus': 883,
#  'warahmatullahi': 884,
#  'partner': 885,
#  '13': 886,
#  'terikirim': 887,
#  'rezeki': 888,
#  'random': 889,
#  'anggap': 890,
#  'tunjuk': 891,
#  'kini': 892,
#  'khawatir': 893,
#  'jauh': 894,
#  'selenggara': 895,
#  'withdraw': 896,
#  'teliti': 897,
#  'sejahtera': 898,
#  'serah': 899,
#  'normal': 900,
#  'segala': 901,
#  'cerah': 902,
#  'saling': 903,
#  'idr': 904,
#  'luar': 905,
#  'kampus': 906,
#  'tiket': 907,
#  'free': 908,
#  'rangga': 909,
#  'diskusi': 910,
#  'file': 911,
#  'tempel': 912,
#  'hilal': 913,
#  '0x30': 914,
#  'mcomm': 915,
#  'hendro': 916,
#  'wd': 917,
#  'mig': 918,
#  'konten': 919,
#  'tuntut': 920,
#  'terimakasih': 921,
#  'app': 922,
#  'singkat': 923,
#  'apresiasi': 924,
#  'disiplin': 925,
#  'tinggi': 926,
#  'wilayah': 927,
#  'kualitas': 928,
#  'mobile': 929,
#  'skema': 930,
#  'notifikasi': 931,
#  'registrasi': 932,
#  'sukses': 933,
#  'total': 934,
#  'beritahukan': 935,
#  'mati': 936,
#  'erti': 937,
#  'tangan': 938,
#  'cantum': 939,
#  'puas': 940,
#  'waalaikumsalam': 941,
#  'tengah': 942,
#  'simpel': 943,
#  'kandidat': 944,
#  'rentang': 945,
#  'website': 946,
#  'kompetitif': 947,
#  'store': 948,
#  'cerita': 949,
#  'maupun': 950,
#  'bareng': 951,
#  'purwadhika': 952,
#  'sabrina': 953,
#  'sibuk': 954,
#  'senin': 955,
#  'desember': 956,
#  'main': 957,
#  'language': 958,
#  'jadwal': 959,
#  'wawancara': 960,
#  'ketemu': 961,
#  'mentor': 962,
#  'jatuh': 963,
#  'motor': 964,
#  'salin': 965,
#  'ira': 966,
#  'pointer': 967,
#  'baterai': 968,
#  'erwin': 969,
#  'offline': 970,
#  'nomer': 971,
#  'bakrim': 972,
#  '50k': 973,
#  '30k': 974,
#  '3jt': 975,
#  '200k': 976,
#  'sidang': 977,
#  '1945': 978,
#  'pasal': 979,
#  'ayat': 980,
#  'ratarata': 981,
#  'manager': 982,
#  'contacts': 983,
#  'cowok': 984,
#  'idgmail': 985,
#  '21jt': 986,
#  'rp185': 987,
#  '2260': 988,
#  'an': 989,
#  'peser': 990,
#  'feb': 991,
#  'whatsapp6283830991389': 992,
#  '800rb15000rb': 993,
#  'rp80k150k': 994,
#  'whatsapp6287833087356': 995,
#  'riska': 996,
#  'other': 997,
#  'networks': 998,
#  'tebak': 999,
#  'tilang': 1000,
#  ...}

# %%
tokenizer_word_json = tokenizer_word_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/TUGAS AKHIR/Notebook/PESAN TEKS/Tokenizer/tokenizer_word_level.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_word_json))
