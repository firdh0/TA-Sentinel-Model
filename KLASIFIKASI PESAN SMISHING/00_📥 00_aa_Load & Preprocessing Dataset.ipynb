# %% [markdown]
# # 🎯 **Step 0: Import Library**
# ---

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🎯 **Step 1: Load Dataset**
# ---

# %% [markdown]
# ## ✨ 1.1 - Dataset Pesan Teks Phishing

# %%
path = '/content/drive/MyDrive/TUGAS AKHIR/Dataset/PESAN TEKS/aa_pesan-teks-phishing.csv'

df_phishing = pd.read_csv(path)

df_phishing.head()
# Out:
#                                                 Data  Category
# 0  PEMBERITAHUAN RESMI\n\nAnda Terdaftar Sebagai ...  phishing
# 1  SELAMAT ANDA TERPILIH SEBAGAI PENERIMA DANA BA...  phishing
# 2  Langsung dapat ekstra 100% di depan\nUntuk pen...  phishing
# 3  PEMBERITAHUAN RESMI\nSelamat ANDA TERPILIH Seb...  phishing
# 4  Gapai impianmu dsni, Ksmpatan emas\ninfo pst j...  phishing

# %% [markdown]
# ## ✨ 1.2 - Dataset Pesan Teks Non Phishing

# %%
path = '/content/drive/MyDrive/TUGAS AKHIR/Dataset/PESAN TEKS/bb_pesan-teks-nonphishing.csv'

df_nonphishing = pd.read_csv(path)

df_nonphishing.head()
# Out:
#                                                 Data      Category
# 0  🔔 HARI TERAKHIR UNTUK DAPATKAN PROMO JOB CONNE...  non-phishing
# 1  🚀 EXCLUSIVE PROMO JOB CONNECTOR ON CAMPUS UP T...  non-phishing
# 2  🔔 3 HARI LAGI PROMO BERAKHIR UNTUK PROGRAM JOB...  non-phishing
# 3  🔔 HARI TERAKHIR PROMO EARLY BIRD INTAKE APRIL-...  non-phishing
# 4  🔔 3 HARI LAGI PROMO EARLY BIRD INTAKE APRIL-JU...  non-phishing

# %% [markdown]
# # 🎯 **Step 2: Preprocess Dataset**
# ---

# %% [markdown]
# ## ✨ 2.1 - Check the amount of data

# %% [markdown]
# ### 📫 2.1.1 - Phishing

# %%
df_phishing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      944 non-null    object
#  1   Category  944 non-null    object
# dtypes: object(2)
# memory usage: 14.9+ KB

# %%
len(df_phishing)
# Out:
# 944

# %% [markdown]
# ### 📫 2.1.2 - Non-phishing

# %%
df_nonphishing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      955 non-null    object
#  1   Category  955 non-null    object
# dtypes: object(2)
# memory usage: 15.0+ KB

# %%
len(df_nonphishing)
# Out:
# 955

# %% [markdown]
# ## ✨ 2.2 - Check and remove duplicate data

# %% [markdown]
# ### 📫 2.2.1 - Phishing

# %%
df_phishing.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 📫 2.2.2 - Non-phishing

# %%
df_nonphishing.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## ✨ 2.3 - Balance the amount of data for each category

# %%
len(df_phishing), len(df_nonphishing)
# Out:
# (944, 955)

# %%
# df_phishing = df_phishing.head(1623205)

# %%
# df_phishing_random = df_phishing.sample(n=500000, random_state=42)
# df_nonphishing_random = df_nonphishing.sample(n=500000, random_state=42)

# %%
# len(df_phishing_random), len(df_nonphishing_random)
# Out:
# (500000, 500000)

# %%
# df_phishing.head()

# %%
# df_phishing_random.head()

# %%
# df_nonphishing.head()

# %%
# df_nonphishing_random.head()

# %% [markdown]
# # 🎯 **Step 3: Combining Into One Dataset**
#
# ---

# %%
# df_url = pd.concat([df_phishing, df_nonphishing])

# df_url.head()
# Out:
#    Category                                                URL
# 0  phishing  logtelstra2021.ddnsking.com/0dfa1b53b835500696...
# 1  phishing  dvsber.ru/modules/mod_ariimageslidersa/KRENK3N...
# 2  phishing  kimsinc564.000webhostapp.com/notification.php?...
# 3  phishing                                     benjim.com/all
# 4  phishing                    www.m.micesrunescape.com-we.ru/

# %%
df_message = pd.concat([df_phishing, df_nonphishing])

df_message.head()
# Out:
#                                                 Data  Category
# 0  PEMBERITAHUAN RESMI\n\nAnda Terdaftar Sebagai ...  phishing
# 1  SELAMAT ANDA TERPILIH SEBAGAI PENERIMA DANA BA...  phishing
# 2  Langsung dapat ekstra 100% di depan\nUntuk pen...  phishing
# 3  PEMBERITAHUAN RESMI\nSelamat ANDA TERPILIH Seb...  phishing
# 4  Gapai impianmu dsni, Ksmpatan emas\ninfo pst j...  phishing

# %%
df_message.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1899 entries, 0 to 954
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      1899 non-null   object
#  1   Category  1899 non-null   object
# dtypes: object(2)
# memory usage: 44.5+ KB

# %% [markdown]
# # 🎯 **Step 4: Save the Dataset**
#
# ---

# %%
file_path = '/content/drive/MyDrive/TUGAS AKHIR/Dataset/PESAN TEKS/df_message.csv'

df_message.to_csv(file_path, index=False)

# %%
df_message.duplicated().sum()
# Out:
# 0
